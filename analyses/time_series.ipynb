# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/World Energy Consumption.csv')

# %%
df.head()
# Out:
#          country  year iso_code  population  gdp  biofuel_cons_change_pct  \
# 0  ASEAN (Ember)  2000      NaN         NaN  NaN                      NaN
# 1  ASEAN (Ember)  2001      NaN         NaN  NaN                      NaN
# 2  ASEAN (Ember)  2002      NaN         NaN  NaN                      NaN
# 3  ASEAN (Ember)  2003      NaN         NaN  NaN                      NaN
# 4  ASEAN (Ember)  2004      NaN         NaN  NaN                      NaN
#
#    biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# 0                      NaN                      NaN                  NaN
# 1                      NaN                      NaN                  NaN
# 2                      NaN                      NaN                  NaN
# 3                      NaN                      NaN                  NaN
# 4                      NaN                      NaN                  NaN
#
#    biofuel_elec_per_capita  ...  solar_share_elec  solar_share_energy  \
# ...

# %%
from src.preprocessing.create_world_df import create_world_df
create_world_df(df)

# %%
df_world = pd.read_csv('world_df.csv')

# %%
filtered_columns = [col for col in df_world.columns if 'consumption' in col.lower()]
filtered_columns.append('year')
strings_to_remove = ['primary_energy_consumption']
filtered_columns = list(filter(lambda item: item not in strings_to_remove,filtered_columns))
df_filtered = df_world[filtered_columns]

# %%
import pandas as pd
import plotly.graph_objects as go


renewable_cols = ['hydro_consumption', 'solar_consumption', 'wind_consumption', 'biofuel_consumption', 'other_renewable_consumption', 'renewables_consumption']
non_renewable_cols = ['coal_consumption', 'gas_consumption', 'oil_consumption', 'fossil_fuel_consumption']
nuclear_cols = ['nuclear_consumption']

# Sort by year and sum the consumption per category per year
df = df_world.sort_values(by='year')
df['Renewable'] = df[renewable_cols].sum(axis=1)
df['Non_Renewable'] = df[non_renewable_cols].sum(axis=1)
df['Nuclear'] = df[nuclear_cols].sum(axis=1)

# Create a Plotly graph
fig = go.Figure()

# Adding traces
fig.add_trace(go.Scatter(x=df['year'], y=df['Renewable'], mode='lines+markers', name='Renewable Energy Consumption', line=dict(color='green')))
fig.add_trace(go.Scatter(x=df['year'], y=df['Non_Renewable'], mode='lines+markers', name='Non-Renewable Energy Consumption', line=dict(color='darkred')))
fig.add_trace(go.Scatter(x=df['year'], y=df['Nuclear'], mode='lines+markers', name='Nuclear Energy Consumption', line=dict(color='blue')))

# Layout settings
fig.update_layout(
    title='Energy Consumption Over Years',
    xaxis_title='Year',
    yaxis_title='Energy Consumption - Measured in terawatt-hours',
    legend_title='Energy Types',
    template='plotly_white'
)

# Save the plot as an HTML file
fig.write_html('plot_aggregated_world.html')

# %%
df_world.year)
# Out:
# pandas.core.series.Series

# %%
import pandas as pd
import plotly.graph_objects as go

# Assuming df_world is your original DataFrame containing the relevant data
# and it has already been loaded correctly

# Define the columns for renewable, non-renewable, and nuclear energy consumption
renewable_cols = ['hydro_consumption', 'solar_consumption', 'wind_consumption', 'biofuel_consumption', 'other_renewable_consumption', 'renewables_consumption']
non_renewable_cols = ['coal_consumption', 'gas_consumption', 'oil_consumption', 'fossil_fuel_consumption']
nuclear_cols = ['nuclear_consumption']

# Sort by year and sum the consumption per category per year
df_world.sort_values(by='year', inplace=True)

# Filter the DataFrame to include only data after 1950
df_filtered = df_world[df_world['year'] > 1950]

# Sum the consumption for each energy category
df_filtered['Renewable'] = df_filtered[renewable_cols].sum(axis=1)
df_filtered['Non_Renewable'] = df_filtered[non_renewable_cols].sum(axis=1)
df_filtered['Nuclear'] = df_filtered[nuclear_cols].sum(axis=1)

# Create a Plotly graph
fig = go.Figure()

# Adding traces for each energy type with data filtered post-1950
fig.add_trace(go.Scatter(x=df_filtered['year'], y=df_filtered['Renewable'], mode='lines+markers', name='Renewable Energy Consumption', line=dict(color='green')))
fig.add_trace(go.Scatter(x=df_filtered['year'], y=df_filtered['Non_Renewable'], mode='lines+markers', name='Non-Renewable Energy Consumption', line=dict(color='red')))
fig.add_trace(go.Scatter(x=df_filtered['year'], y=df_filtered['Nuclear'], mode='lines+markers', name='Nuclear Energy Consumption', line=dict(color='blue')))

# Layout settings
fig.update_layout(
    title='Energy Consumption Over Years (Post-1950)',
    xaxis_title='Year',
    yaxis_title='Energy Consumption - Measured in terawatt-hours',
    legend_title='Energy Types',
    template='plotly_white'
)

# Save the plot as an HTML file
fig.write_html('plot_aggregated_world_post_1950.html')
print("Plot saved as 'plot_aggregated_world_post_1950.html'")
# Out:
# Plot saved as 'plot_aggregated_world_post_1950.html'
# /var/folders/19/2pb1lbcd5c55tc1_wscxp2jw0000gn/T/ipykernel_33779/1286462987.py:19: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/19/2pb1lbcd5c55tc1_wscxp2jw0000gn/T/ipykernel_33779/1286462987.py:20: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/19/2pb1lbcd5c55tc1_wscxp2jw0000gn/T/ipykernel_33779/1286462987.py:21: SettingWithCopyWarning:
#
#
# ...

# %%
import pandas as pd
import plotly.graph_objects as go

# Assuming df_world is pre-loaded with the correct data
# Define columns for different energy types
renewable_cols = ['hydro_consumption', 'solar_consumption', 'wind_consumption', 'biofuel_consumption', 'other_renewable_consumption', 'renewables_consumption']
non_renewable_cols = ['coal_consumption', 'gas_consumption', 'oil_consumption', 'fossil_fuel_consumption']
nuclear_cols = ['nuclear_consumption']

# Sort by year and filter the DataFrame to include only data after 1950
df_world.sort_values(by='year', inplace=True)
df_filtered = df_world[df_world['year'] > 1950].copy()  # Use .copy() to avoid SettingWithCopyWarning

# Sum the consumption for each energy category using .loc to safely assign values
df_filtered.loc[:, 'Renewable'] = df_filtered[renewable_cols].sum(axis=1)
df_filtered.loc[:, 'Non_Renewable'] = df_filtered[non_renewable_cols].sum(axis=1)
df_filtered.loc[:, 'Nuclear'] = df_filtered[nuclear_cols].sum(axis=1)

# Create a Plotly graph
fig = go.Figure()

# Adding traces for each energy type
fig.add_trace(go.Scatter(
    x=df_filtered['year'], 
    y=df_filtered['Renewable'], 
    mode='lines+markers', 
    name='Renewable Energy Consumption', 
    line=dict(color='green')
))
fig.add_trace(go.Scatter(
    x=df_filtered['year'], 
    y=df_filtered['Non_Renewable'], 
    mode='lines+markers', 
    name='Non-Renewable Energy Consumption', 
    line=dict(color='red')
))
fig.add_trace(go.Scatter(
    x=df_filtered['year'], 
    y=df_filtered['Nuclear'], 
    mode='lines+markers', 
    name='Nuclear Energy Consumption', 
    line=dict(color='blue')
))

# Layout settings
fig.update_layout(
    title='Energy Consumption Over Years ',
    xaxis_title='Year',
    yaxis_title='Energy Consumption - Measured in terawatt-hours',
    legend_title='Energy Types',
    template='plotly_white'
)

# Save the plot as an HTML file
fig.write_html('./outputs/plot_aggregated_world.html')
